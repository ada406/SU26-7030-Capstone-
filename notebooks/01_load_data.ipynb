# %% [markdown]
# # 01 — Download & load Spotify tracks data
#
# **Research question:** How accurately can a supervised model predict a song's genre from Spotify audio features alone?
#
# This notebook only covers data access:
# 1. Download the [Kaggle Spotify Tracks dataset](https://www.kaggle.com/datasets/maharshipandya/-spotify-tracks-dataset)
# 2. Load `data/raw/dataset.csv`
# 3. Confirm shape, `track_genre`, and audio feature columns
#
# **Note:** Graders can demo the committed model + Streamlit app **without** this dataset.
# You need the CSV for song lookup and for retraining.
# **Canonical CLI:** `python scripts/download_data.py` then `python scripts/load_data.py`.
#
# Run with the `spotify-genre-prediction` conda env / kernel.

# %%
import sys
from pathlib import Path

PROJECT_ROOT = Path.cwd().resolve()
if PROJECT_ROOT.name == "notebooks":
    PROJECT_ROOT = PROJECT_ROOT.parent
elif not (PROJECT_ROOT / "src").exists():
    PROJECT_ROOT = Path("..").resolve()

sys.path.insert(0, str(PROJECT_ROOT))
print("Project root:", PROJECT_ROOT)

from src.data_io import (
    AUDIO_FEATURES,
    KAGGLE_URL,
    RAW_CSV_PATH,
    TARGET_COLUMN,
    download_dataset,
    load_raw_tracks,
    print_load_report,
    raw_csv_exists,
    summarize_tracks,
)

# %% [markdown]
# ## Download
#
# **Automatic (Kaggle API):** needs `~/.kaggle/kaggle.json` and accepting dataset terms on the Kaggle page.
#
# **Manual:** download the ZIP from the link below, put the ZIP or `dataset.csv` in `data/raw/`, then run the next cell (it will unzip if needed).
#
# Dataset page: https://www.kaggle.com/datasets/maharshipandya/-spotify-tracks-dataset

# %%
print("Expected CSV:", RAW_CSV_PATH)
print("Kaggle page:", KAGGLE_URL)
print("Already present?", raw_csv_exists())

csv_path = download_dataset()
csv_path

# %% [markdown]
# ## Load & validate
#
# We expect ~100k+ rows, a `track_genre` label column, and Spotify audio feature columns (danceability, energy, etc.).

# %%
df = load_raw_tracks()
print_load_report(df)

# %%
summary = summarize_tracks(df)
display(df[AUDIO_FEATURES + [TARGET_COLUMN]].head())
print("Rows:", summary["n_rows"])
print("Unique fine-grained genres:", summary["n_genres"])
print("Missing audio features:", summary["missing_audio_features"])

# %% [markdown]
# ## Success criteria
#
# - [ ] Conda env builds from `environment.yml`
# - [ ] `dataset.csv` is in `data/raw/`
# - [ ] This notebook (or `python scripts/load_data.py`) prints shape + genre counts without errors
#
# Next: `02_train_model.ipynb` (or `python scripts/train_model.py --model rf --no-tune`).
